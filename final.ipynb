# %%
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in d:\anaconda_envs\ai_env\lib\site-packages (1.43.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (2.41.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (2.11.9)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in d:\anaconda_envs\ai_env\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\anaconda_envs\ai_env\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda_envs\ai_env\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda_envs\ai_env\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\anaconda_envs\ai_env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda_envs\ai_env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda_envs\ai_env\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in d:\anaconda_envs\ai_env\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\anaconda_envs\ai_env\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda_envs\ai_env\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda_envs\ai_env\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\anaconda_envs\ai_env\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anaconda_envs\ai_env\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda_envs\ai_env\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda_envs\ai_env\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\anaconda_envs\ai_env\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
import whisper
import queue, threading, time
import numpy as np
from scipy.io.wavfile import write as wv
import tempfile, os
import sounddevice as sd
import pyttsx3
from datetime import datetime 
import pickle 
import face_recognition
import cv2
from pathlib import Path 
from google import genai
from dotenv import load_dotenv
import requests, json
import smtplib

from google.genai import types

# %%
load_dotenv()
# Out:
# True

# %%
import hashlib,hmac,secrets,string,base64
from IPython.display import display, clear_output
import ipywidgets as widgets

# %%
class EnrollmentTool:
    def __init__(self):
        pass

# %%
class AIGuardAgent:
    def __init__(self):
        self.model = whisper.load_model("base.en")
        self.SAMPLE_RATE = 16000
        self.CHUNK_SECONDS = 2
        self.audio_queue = queue.Queue(maxsize=10)
        
        self.tts_engine = pyttsx3.init()
        self.tts_engine.setProperty('rate', 150)
        
        self.guard_mode = False
        self.listening = False
        self.stop_flag = False
        self.alarm_activated = False
        
        self.face_db_path = "face_database.pkl"
        self.ensure_face_db_directory()
        self.load_trusted_faces()
        
        # FIXED: Better camera management
        self.camera = None
        self.camera_lock = threading.Lock()
        self.camera_in_use = False
        self.current_camera_thread = None


        # Thread safety
        self.thread_lock = threading.Lock()
        self.camera = None
        self.camera_lock = threading.Lock()
        
        # NEW: Authority notification settings
        
        
        # Face tracking
        self.unknown_person_tracker = {}
        self.conversation_memory = {}
        self.situation_context = {
            "time_of_day": "",
            "last_recognized_person": "",
            "recent_events": []
        }
        
        self.escalation_levels = {
            1: "polite warning",
            2: "firm warning", 
            3: "final warning"
        }
        
        self.activation_phrases = [
            "guard my room", "protect my room", "secure my room", 
            "start guard mode", "activate guard"
        ]
        
        self.deactivation_phrases = [
            "stop guard mode", "deactivate guard", "stand down",
            "stop monitoring", "goodbye guard"
        ]
        
        self.enrollment_phrases = [
            "enroll face", "register face", "add trusted person"
        ]
        
        self.current_dialog_context = ""
        self.setup_llm()

    
        
        # Webhook configuration
        self.webhook_urls = os.getenv('WEBHOOKS')
        
        # Load from environment variables (more secure)
        self._load_notification_config()
    ####################################
    #      RESOURCE MANAGEMENT         #
    ####################################    
    def _load_notification_config(self):
        """Load notification config from environment variables"""
        import os
        
        
        # Webhook URLs from environment
        webhook_env = os.getenv('GUARD_WEBHOOKS', '')
        if webhook_env:
            self.webhook_urls = webhook_env.split(',')
        
        print(f"Notification system configured for Slack")
    
    def send_webhook_alert(self, alert_data):
        """Send alerts to various webhook services"""
        # Ensure webhook_urls is a list, not a string
        if not hasattr(self, 'webhook_urls') or not self.webhook_urls:
            print("⚠️ No webhook URLs configured")
            return False
        
        if isinstance(self.webhook_urls, str):
            print("⚠️ webhook_urls is a string, converting to list")
            self.webhook_urls = [self.webhook_urls] if self.webhook_urls else []
        
        successful_webhooks = 0
        
        # Slack-style webhook
        slack_payload = {
            "text": f"🚨 AI GUARD ALERT: {alert_data['message']}",
            "attachments": [
                {
                    "color": "danger",
                    "fields": [
                        {"title": "Time", "value": alert_data['timestamp'], "short": True},
                        {"title": "Level", "value": str(alert_data['level']), "short": True},
                        {"title": "Location", "value": "Your Room", "short": True}
                    ]
                }
            ]
        }
        
        print(f"→ Attempting to send webhooks to {len(self.webhook_urls)} endpoint(s)...")
        
        # Try each webhook URL
        for idx, webhook_url in enumerate(self.webhook_urls):
            try:
                print(f"→ Webhook {idx + 1}/{len(self.webhook_urls)}: {webhook_url[:50]}...")
                
                if 'slack.com' in webhook_url:
                    payload = slack_payload
                else:
                    # Generic webhook
                    payload = {
                        "alert": True,
                        "message": alert_data['message'],
                        "timestamp": alert_data['timestamp'],
                        "level": alert_data['level'],
                        "system": "AI Room Guard"
                    }
                
                response = requests.post(
                    webhook_url, 
                    json=payload, 
                    headers={'Content-Type': 'application/json'},
                    timeout=10
                )
                
                if response.status_code in [200, 204]:
                    print(f"✅ Webhook alert sent successfully to endpoint {idx + 1}")
                    successful_webhooks += 1
                else:
                    print(f"❌ Webhook failed with status {response.status_code}: {response.text[:100]}")
                    
            except requests.exceptions.Timeout:
                print(f"⏱️ Webhook timeout for endpoint {idx + 1}")
            except requests.exceptions.ConnectionError:
                print(f"🔌 Connection error for webhook endpoint {idx + 1}")
            except Exception as e:
                print(f"❌ Webhook error for endpoint {idx + 1}: {e}")
        
        print(f"📊 Webhook summary: {successful_webhooks}/{len(self.webhook_urls)} successful")
        return successful_webhooks > 0    
    

    def ensure_face_db_directory(self):
        os.makedirs(os.path.dirname(self.face_db_path) or ".", exist_ok=True)
    def get_camera(self):
        """Thread-safe camera access with proper resource management"""
        with self.camera_lock:
            if self.camera is None or not self.camera.isOpened():
                try:
                    self.camera = cv2.VideoCapture(0)
                    if self.camera.isOpened():
                        self.camera.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
                        self.camera.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
                        self.camera.set(cv2.CAP_PROP_FPS, 15)
                        print("Camera opened successfully")
                        return self.camera
                    else:
                        print("Failed to open camera")
                        return None
                except Exception as e:
                    print(f"Camera error: {e}")
                    return None
            return self.camera

    def safe_camera_release(self):
        """Safely release camera with multiple attempts"""
        with self.camera_lock:
            if self.camera is not None:
                print("Releasing camera...")
                max_attempts = 3
                for attempt in range(max_attempts):
                    try:
                        self.camera.release()
                        self.camera = None
                        print("Camera released successfully")
                        break
                    except Exception as e:
                        print(f"Camera release attempt {attempt + 1} failed: {e}")
                        time.sleep(0.1)
                # Force cleanup
                cv2.destroyAllWindows()
    
    def force_camera_cleanup(self):
        """Force cleanup of all camera resources"""
        print("Force cleaning up camera resources...")
        self.safe_camera_release()
        
        # Additional cleanup
        try:
            # Close any remaining OpenCV windows
            cv2.destroyAllWindows()
            
            # Sometimes we need to wait a bit for resources to free
            time.sleep(0.5)
            
            # Try to open and immediately close a camera to reset state
            temp_cam = cv2.VideoCapture(0)
            if temp_cam.isOpened():
                temp_cam.release()
            cv2.destroyAllWindows()
            
        except Exception as e:
            print(f"Note during force cleanup: {e}")

    def load_trusted_faces(self):
        """Robust face database loading"""
        try:
            if os.path.exists(self.face_db_path):
                with open(self.face_db_path, 'rb') as f:
                    data = pickle.load(f)
                    self.known_face_encodings = data['encodings']
                    self.known_face_names = data['names']
                print(f"Loaded {len(self.known_face_names)} trusted faces")
            else:
                print("No face database found. Starting fresh.")
                self.known_face_encodings = []
                self.known_face_names = []
        except Exception as e:
            print(f"Error loading face database: {e}")
            self.known_face_encodings = []
            self.known_face_names = []

    def save_trusted_faces(self):
        """Save trusted faces to database"""
        try:
            with open(self.face_db_path, 'wb') as f:
                pickle.dump({
                    'encodings': self.known_face_encodings,
                    'names': self.known_face_names
                }, f)
            print(f"Saved {len(self.known_face_names)} faces to database")
        except Exception as e:
            print(f"Error saving face database: {e}")

    

    def _find_or_create_person_id(self,encoding):
        """Find existing person or create new ID"""
        # Check if this face matches any existing unknown person
        for person_id, data in self.unknown_person_tracker.items():
            stored_encoding = data['reference_encoding']
            distance = np.linalg.norm(stored_encoding - encoding)
            if distance < 0.6:  # Similarity threshold
                return person_id
        
        # New person - create ID
        new_id = max(self.unknown_person_tracker.keys(), default=0) + 1
        return new_id

    
    def _create_new_tracker(self, face_encoding):
        """Create new person tracker"""
        return {
            'reference_encoding': face_encoding,
            'first_seen': time.time(),
            'last_seen': time.time(),
            'escalation_level': 1,
            'response_cooldown': 10,
            'appearances': 1,
            'last_interaction': time.time()
        }

  
    
    def _update_situation_context(self):
        """Update dynamic context for better responses"""
        hour = datetime.now().hour
        if 5 <= hour < 12:
            time_desc = "morning"
        elif 12 <= hour < 18:
            time_desc = "afternoon" 
        else:
            time_desc = "evening"
        
        self.situation_context['time_of_day'] = time_desc

    def _format_conversation_history(self, history):
        """Format conversation history for LLM"""
        if not history:
            return "No previous conversation"
        return "\n".join([f"{speaker}: {text}" for speaker, text in history])

    def _get_fallback_response(self, escalation_level):
        """Fallback responses when LLM fails"""
        fallbacks = {
            1: "Hello, who are you and what are you doing here?",
            2: "I need you to leave this area immediately.",
            3: "Final warning! Security is being notified. Leave now!"
        }
        return fallbacks.get(escalation_level, "Please identify yourself.")

    




    def setup_llm(self):
        """Configure Google GenAI with error handling (using google-genai)"""
        api_key = os.getenv('GEMINI_API_KEY')
        if not api_key:
            print("⚠️ GEMINI_API_KEY not found in environment variables")
            return
        self.client = genai.Client(api_key=api_key)
        models = ['gemini-2.5-flash','gemini-2.5-pro','gemini-pro']
        for model_name in models:
            try:
                check = self.client.models.generate_content(
                    model=model_name,
                    contents="Say OK",
                    config=None
                )
                if hasattr(check, "text") and check.text.strip().upper() == "OK":
                    print(f"✅ Loaded model: {model_name}")
                    return
            except Exception as e:
                print(f"⚠️ {model_name} error: {e}")
        print("❌ No working Gemini model found.")
        self.llm_model = None

    
    def activate_alarm_protocol(self):
        """Real alarm functionality for level 3 escalation"""
        if self.alarm_activated:
            return
            
        self.alarm_activated = True
        
        # Visual alarm
        alarm_thread = threading.Thread(target=self._flash_alarm, daemon=True)
        alarm_thread.start()
        
        # Audio alarm
        self.speak("INTRUDER ALERT! Security has been notified! Leave immediately!")
        
        # Notify authorities
        self.notify_authorities(3)
        
        print("ALARM ACTIVATED - Authorities notified")

    def _flash_alarm(self):
        """Visual alarm display"""
        while self.alarm_activated and self.guard_mode:
            # Create flashing alert window
            for color in [(0, 0, 255), (0, 0, 0)]:  # Red, Black
                alert_frame = np.zeros((200, 600, 3), dtype=np.uint8)
                alert_frame[:] = color
                
                cv2.putText(alert_frame, "INTRUDER ALERT!", (50, 100),
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 3)
                cv2.imshow("ALERT - INTRUDER DETECTED", alert_frame)
                cv2.waitKey(500)  # Flash every 500ms
                
        cv2.destroyWindow("ALERT - INTRUDER DETECTED")

    def notify_authorities(self, escalation_level, context=""):
        """Complete authority notification system"""
        alert_data = {
            'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
            'level': f"Level {escalation_level}",
            'message': self._get_alert_message(escalation_level, context)
        }
        
        print(f"NOTIFYING AUTHORITIES: {alert_data['message']}")
        
        success_count = 0
        
        # Level 1-2: Basic notifications
        if escalation_level >= 1:
            # Log to file (always works)
            self._log_alert_to_file(alert_data)
            success_count += 1
            
            # Email alert for level 2+
            if escalation_level >= 2:
                
                if self.send_webhook_alert(alert_data):
                    success_count += 1
        
        # Level 3: Full emergency notifications
        if escalation_level >= 3:
            # Webhook alerts
            if self.send_webhook_alert(alert_data):
                success_count += 1
            
            
            
            
            
            # Additional emergency contacts
        print(f"{success_count} notification methods successful")
        return success_count > 0

    def _get_alert_message(self, escalation_level, context):
        """Generate appropriate alert message"""
        messages = {
            1: f"Unknown person detected. {context}",
            2: f"UNKNOWN PERSON WARNING: Person has not left after initial warning. {context}",
            3: f"INTRUDER ALERT: Unknown person remains after multiple warnings! {context}"
        }
        return messages.get(escalation_level, f"Security alert: {context}")

    def _log_alert_to_file(self, alert_data):
        """Always log alerts to local file"""
        try:
            with open("security_alerts.log", "a", encoding='utf-8') as f:
                f.write(f"{alert_data['timestamp']} - {alert_data['level']}: {alert_data['message']}\n")
            print("Alert logged to security_alerts.log")
        except Exception as e:
            print(f"Failed to log alert: {e}")

    
    def _capture_evidence_frame(self, frame, person_id):
        """Save photo evidence of intruder"""
        try:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"evidence_person_{person_id}_{timestamp}.jpg"
            cv2.imwrite(filename, frame)
            print(f" Evidence saved: {filename}")
        except Exception as e:
            print(f"Failed to save evidence: {e}")
    def _find_matching_person(self,encoding,threshold=0.1):
        for person_id, data in self.unknown_person_tracker.items():
            stored_encoding = data['reference_encoding']
            distance = np.linalg.norm(stored_encoding - encoding)
            if distance < threshold:
                return person_id
        return None 
 
    


    def speak(self, text):
        """Text to speech with error handling"""
        try:
            self.tts_engine.say(text)
            self.tts_engine.runAndWait()
        except Exception as e:
            print(f"TTS error: {e}")
    
    
    
    def enroll_using_webcam(self, name="unknown"):
        """Face enrollment with proper camera cleanup"""
        camera = self.get_camera()
        if not camera or not camera.isOpened():
            self.speak("Cannot access camera for enrollment.")
            return False

        self.speak(f"Please look at the camera for face enrollment as {name}")

        enrollment_frames = []
        frames_captured = 0
        max_frames = 10  # Reduced for faster enrollment
        
        try:
            while frames_captured < max_frames and not self.stop_flag:
                ret, frame = camera.read()
                if not ret:
                    print(" Failed to capture frame")
                    continue
                
                rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                face_locations = face_recognition.face_locations(rgb_frame)
                face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)
                
                if len(face_encodings) == 1:
                    enrollment_frames.append(face_encodings[0])
                    frames_captured += 1
                    print(f" Captured face frame {frames_captured}/{max_frames}")
                    
                    cv2.putText(frame, f"Enrolling: {frames_captured}/{max_frames}", 
                               (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
                
                cv2.imshow("Face Enrollment - Press 'q' to cancel", frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
                
                time.sleep(0.3)
            
            if enrollment_frames:
                avg_encoding = np.mean(enrollment_frames, axis=0)
                self.known_face_encodings.append(avg_encoding)
                self.known_face_names.append(name)
                self.save_trusted_faces()
                self.speak(f"Successfully enrolled {name} as a trusted person")
                return True
            else:
                self.speak("Failed to capture face. Please try again.")
                return False
                
        except Exception as e:
            print(f"Enrollment error: {e}")
            self.speak("Error during face enrollment.")
            return False
        finally:
            # ALWAYS cleanup
            cv2.destroyAllWindows()
            print("Enrollment camera cleanup completed")
        
    # === FIXED MIC STREAM ===
    def mic_stream(self):
        """Capture microphone audio in chunks"""
        def callback(indata, frames, time, status):
            if status:
                print(f"Audio status: {status}")
            if not self.audio_queue.full():  # Prevent queue overload
                self.audio_queue.put(indata.copy())
        
        try:
            with sd.InputStream(
                samplerate=self.SAMPLE_RATE, 
                channels=1, 
                dtype='int16', 
                callback=callback,
                blocksize=int(self.SAMPLE_RATE * self.CHUNK_SECONDS)
            ):
                print(" Microphone stream started")
                while not self.stop_flag:
                    time.sleep(0.1)
        except Exception as e:
            print(f"Microphone error: {e}")
        finally:
            print(" Microphone stream stopped")


    def check_activation_command(self, text):
        """Check if text contains any activation phrase"""
        return any(phrase in text for phrase in self.activation_phrases)
    
    def check_deactivation_command(self, text):
        """Check if text contains any deactivation phrase"""
        return any(phrase in text for phrase in self.deactivation_phrases)
    
    def check_enrollment_command(self, text):
        """Check if text contains face enrollment phrase"""
        return any(phrase in text for phrase in self.enrollment_phrases)
    
    def activate_guard_mode(self):
        """Activate guard mode with proper resource management"""
        self.guard_mode = True
        self.unknown_person_tracker = {}
        self.conversation_memory = {}
        self.alarm_activated = False
        
        self.speak("Guard mode activated! Starting face monitoring.")
        print(f"Guard mode ACTIVATED at {datetime.now().strftime('%H:%M:%S')}")
        
        # Start face monitoring in a separate thread
        face_thread = threading.Thread(target=self.face_monitoring_loop, daemon=True)
        face_thread.start()

    
    def deactivate_guard_mode(self):
        """Deactivate guard mode with proper cleanup"""
        print("Deactivating guard mode and cleaning up...")
        self.guard_mode = False
        self.alarm_activated = False
        
        # Allow time for monitoring loop to exit
        time.sleep(0.5)
        
        # Force cleanup
        self.force_camera_cleanup()
        
        self.speak("Guard mode deactivated. Goodbye!")
        print(f"Guard mode DEACTIVATED at {datetime.now().strftime('%H:%M:%S')}")


    def process_audio_chunk(self, chunk):
        """Process audio chunk with Whisper"""
        with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as tmp:
            path = tmp.name
        
        try:
            wv(path, self.SAMPLE_RATE, chunk)
            result = self.model.transcribe(
                path, 
                language="en", 
                fp16=False, 
                condition_on_previous_text=False
            )
            
            text = (result.get("text") or "").strip().lower()
            
            if text:
                print(f"Heard: {text}")
                
                if self.check_activation_command(text) and not self.guard_mode:
                    self.activate_guard_mode()
                elif self.check_deactivation_command(text) and self.guard_mode:
                    self.deactivate_guard_mode()
                elif self.check_enrollment_command(text):
                    self.speak("Starting face enrollment process.")
                    self.enroll_using_webcam()
                elif "how many trusted" in text or "list trusted" in text:
                    count = len(self.known_face_names)
                    if count == 0:
                        self.speak("No trusted faces enrolled yet.")
                    else:
                        self.speak(f"I have {count} trusted faces enrolled.")
                        print(f"Trusted faces: {', '.join(self.known_face_names)}")
                elif self.guard_mode:
                    print(f" In guard mode, heard: {text}")
                    
        except Exception as e:
            print(f"Error processing audio: {e}")
        finally:
            if os.path.exists(path):
                os.remove(path)
    
    def recognize(self, frame):
        """Recognize faces in frame"""
        if not self.known_face_encodings:
            return [], [], []
        
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        face_locations = face_recognition.face_locations(frame_rgb)
        face_encodings = face_recognition.face_encodings(frame_rgb, face_locations)
        
        recognized_names = []
        recognized_status = []
        
        for face_encoding in face_encodings:
            matches = face_recognition.compare_faces(self.known_face_encodings, face_encoding, tolerance=0.5)
            name = "unknown"
            status = "unknown"
            
            face_distances = face_recognition.face_distance(self.known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances) if len(face_distances) > 0 else None
            
            if best_match_index is not None and matches[best_match_index]:
                name = self.known_face_names[best_match_index]
                status = "trusted"
            
            recognized_names.append(name)
            recognized_status.append(status)
        
        return recognized_names, recognized_status, face_encodings
    
    def face_monitoring_loop(self):
        """Face monitoring with proper escalation handling"""
        print("Starting face monitoring loop...")
        camera = self.get_camera()
        
        if not camera or not camera.isOpened():
            self.speak("Error accessing the webcam for face monitoring.")
            print("Error: Could not open webcam.")
            self.guard_mode = False
            return
        
        self.speak("Face monitoring started. Scanning for trusted individuals.")
        last_announcement = {}
        announcement_cd = 10

        try:
            while self.guard_mode and not self.stop_flag:
                ret, frame = camera.read()
                if not ret:
                    print("Failed to capture frame from webcam")
                    time.sleep(1)
                    continue
                
                names, statuses, encodings = self.recognize(frame)
                curr_t = time.time()
                
                for name, status, encoding in zip(names, statuses, encodings):
                    if status == "trusted":
                        if name not in last_announcement or (curr_t - last_announcement[name]) > announcement_cd:
                            self.speak(f"Hello {name}, welcome back!")
                            print(f"✓ Recognized trusted person: {name}")
                            last_announcement[name] = curr_t
                    elif status == "unknown":
                        print(f"🚨 UNKNOWN PERSON DETECTED - Starting escalation process")
                        # Normalize encoding to single array
                        normalized_encoding = encoding[0] if isinstance(encoding, list) else encoding
                        self.handle_unknown_person(normalized_encoding, frame)
                
                # Draw face boxes
                frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                face_locations = face_recognition.face_locations(frame_rgb)
                
                for (top, right, bottom, left), name, status in zip(face_locations, names, statuses):
                    color = (0, 255, 0) if status == "trusted" else (0, 0, 255)
                    cv2.rectangle(frame, (left, top), (right, bottom), color, 2)
                    cv2.putText(frame, f"{name} ({status})", (left, top - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
                
                cv2.imshow("AI Guard - Face Monitoring (Press 'q' to stop)", frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
                    
        except Exception as e:
            print(f"❌ Face monitoring error: {e}")
            import traceback
            traceback.print_exc()
        finally:
            print("Cleaning up face monitoring resources...")
            cv2.destroyAllWindows()
            self.safe_camera_release()
            print("Face monitoring cleanup completed")

    def handle_unknown_person(self, face_encoding, frame):
        """Complete escalation workflow - called automatically during monitoring"""
        if not self.guard_mode:
            print("⚠️ Escalation aborted: Guard mode disabled")
            return
        
        print("→ Processing unknown person escalation...")
        
        try:
            # Ensure face_encoding is a single array, not a list
            person_id = self._find_or_create_person_id(face_encoding)
            
            escalation_level = self._update_person_tracking(person_id, face_encoding)
            current_time = time.time()
            tracker = self.unknown_person_tracker[person_id]
            
            # Check if enough time has passed for next interaction
            if current_time - tracker['last_interaction'] > tracker['response_cooldown']:
                print(f"→ Interaction cooldown expired, proceeding with Level {escalation_level} response")
                
                context = f"Present for {int(current_time - tracker['first_seen'])}s, seen {tracker['appearances']} times"
                
                # Generate and speak response based on escalation level
                response = self.generate_escalation_response(escalation_level, context)
                self.speak(response)
                print(f"🚨 Level {escalation_level} Response: {response}")
                
                # Send notifications based on escalation level
                if escalation_level >= 2:
                    print(f"📧 Sending Level {escalation_level} notifications to authorities")
                    self.notify_authorities(escalation_level, context)
                
                # Level 3: Activate alarm protocol
                if escalation_level == 3:
                    print("🚨 LEVEL 3 ALERT - Activating alarm protocol")
                    self.activate_alarm_protocol()
                    # Take photo evidence
                    self._capture_evidence_frame(frame, person_id)
                
                tracker['last_interaction'] = current_time
            else:
                remaining_cooldown = tracker['response_cooldown'] - (current_time - tracker['last_interaction'])
                print(f"⏳ Interaction cooldown active ({remaining_cooldown:.1f}s remaining)")
                
        except Exception as e:
            print(f"❌ Error in handle_unknown_person: {e}")
            import traceback
            traceback.print_exc()

    

    
    def generate_escalation_response(self, escalation_level, context=""):
        """Generate context-aware escalation response using google-genai"""
        self._update_situation_context()
        history = self.conversation_memory.get(escalation_level, [])
        recent_history = history[-3:]
        escalation_descriptions = ['polite inquiry', 'firm warning', 'final alert']
        description = escalation_descriptions[escalation_level-1] if escalation_level <= 3 else 'critical alert'
        dynamic_prompt = f"""You are a professional security assistant for a home monitoring system.

Current Situation:
- Time of day: {self.situation_context.get('time_of_day','unknown')}
- Alert level: {escalation_level} of 3
- Context: {context}

Your task: Generate a professional {description} message for someone who is not recognized by the system.

Requirements:
- Be polite but firm
- 1-2 sentences maximum
- Professional tone
- No threats or aggressive language
- Focus on requesting identification or suggesting they leave

Previous messages:
{self._format_conversation_history(recent_history) if recent_history else "None"}

Generate the message now:"""
        try:
            if  self.client:
                safety_settings = [
                    {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"},
                    {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
                    {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
                    {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_ONLY_HIGH"},
                ]
                response = self.client.models.generate_content(
                    model="gemini-2.5-flash",
                    contents=[{"role": "user", "parts": [{"text": dynamic_prompt}]}],
                    config=None,

                )
                response_text = (
                    response.text.strip() if hasattr(response, 'text') and response.text else self._get_fallback_response(escalation_level)
                )
            else:
                response_text = self._get_fallback_response(escalation_level)
            self.conversation_memory.setdefault(escalation_level,[]).append(("Guard",response_text))
            return response_text
        except Exception as e:
            print(f"❌ LLM error: {e}")
            import traceback; traceback.print_exc()
            return self._get_fallback_response(escalation_level)

    def _update_person_tracking(self, person_id, face_encoding):
        """Update tracking and determine escalation level"""
        if person_id not in self.unknown_person_tracker:
            self.unknown_person_tracker[person_id] = self._create_new_tracker(face_encoding)
            print(f"→ New unknown person tracked: {person_id}")
            return 1
        
        tracker = self.unknown_person_tracker[person_id]
        current_time = time.time()
        time_present = current_time - tracker['first_seen']
        
        tracker['last_seen'] = current_time
        tracker['appearances'] += 1
        
        # Determine escalation based on time present
        if time_present > 120:  # 2 minutes
            new_level = 3
        elif time_present > 60:  # 1 minute
            new_level = 2
        else:
            new_level = 1
        
        # Only escalate if level increases
        if new_level > tracker['escalation_level']:
            old_level = tracker['escalation_level']
            tracker['escalation_level'] = new_level
            # FIXED: Corrected cooldown list indexing (removed leading 0)
            tracker['response_cooldown'] = [10, 10, 10][new_level - 1]
            print(f"⚠️ Escalation increased: Level {old_level} → Level {new_level} (cooldown: {tracker['response_cooldown']}s)")
        
        return tracker['escalation_level']    

    
    def start_listening(self):
        """Start the system with proper initialization"""
        self.listening = True
        self.stop_flag = False
        
        # Start microphone stream
        audio_thread = threading.Thread(target=self.mic_stream, daemon=True)
        audio_thread.start()
        
        self.speak("AI Guard system ready. Say 'Guard my room' to activate or 'Enroll face' to add trusted persons.")
        print(" Listening for commands...")
        print(f" {len(self.known_face_names)} trusted faces loaded")
        
        try:
            while self.listening and not self.stop_flag:
                if not self.audio_queue.empty():
                    chunk = self.audio_queue.get()
                    self.process_audio_chunk(chunk)
                else:
                    time.sleep(0.1)
                    
        except KeyboardInterrupt:
            print("\n Keyboard interrupt received...")
        except Exception as e:
            print(f"\n Unexpected error: {e}")
        finally:
            # GUARANTEED CLEANUP
            self.stop_listening()
    
    def stop_listening(self):
        """Complete system shutdown with guaranteed cleanup"""
        print("\n Shutting down AI Guard system...")
        
        # Set flags to stop all loops
        self.listening = False
        self.stop_flag = True
        self.guard_mode = False
        self.alarm_activated = False
        
        # Allow time for threads to exit
        time.sleep(1)
        
        # Force cleanup of all resources
        self.force_camera_cleanup()
        
        # Clear queues
        while not self.audio_queue.empty():
            try:
                self.audio_queue.get_nowait()
            except:
                break
                
        print(" AI Guard system shutdown complete")
        print(" Camera should now be released and available for other applications")

# %%
guard=AIGuardAgent()
guard.start_listening()
# Out:
# No face database found. Starting fresh.
# ✅ Loaded model: gemini-2.5-flash
# Notification system configured for Slack
#  Microphone stream started
#  Listening for commands...
#  0 trusted faces loaded
# Heard: you
# Heard: you
# Heard: register phase.
# Heard: you
# Heard: the best i ever could have seen.
# Heard: you
# Heard: rafael the
# Heard: you
# Heard: register face.
# Camera opened successfully
#  Captured face frame 1/10
#  Captured face frame 2/10
#  Captured face frame 3/10
#  Captured face frame 4/10
#  Captured face frame 5/10
#  Captured face frame 6/10
#  Captured face frame 7/10
#  Captured face frame 8/10
#  Captured face frame 9/10
#  Captured face frame 10/10
# Saved 1 faces to database
# Enrollment camera cleanup completed
# Heard: you
# Heard: you
# Heard: you
# Heard: you
# Heard: you
# Heard: you
# Heard: you
# Heard: protect my room.
# Guard mode ACTIVATED at 22:08:57
# Starting face monitoring loop...
# ✓ Recognized trusted person: unknown
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → New unknown person tracked: 1
# ⏳ Interaction cooldown active (10.0s remaining)
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (9.3s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (8.6s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (7.9s remaining)
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (7.2s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (6.5s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (5.8s remaining)
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (5.1s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (4.3s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (3.5s remaining)
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (2.8s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (2.0s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (1.3s remaining)
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (0.6s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 1 response
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# 🚨 Level 1 Response: An unrecognized individual has been detected. Please identify yourself to the camera or exit the monitored area.
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (0.1s remaining)
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 1 response
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# 🚨 Level 1 Response: You remain unidentified within the monitored area. For security purposes, please state your name to the camera or depart the premises promptly.
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (0.1s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 1 response
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# 🚨 Level 1 Response: Your continued presence without identification necessitates further action. Please identify yourself to the camera immediately or you must exit the premises.
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 1 response
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: 2. id... 2. 3. 9. workforce romania about 3.
#  In guard mode, heard: 2. id... 2. 3. 9. workforce romania about 3.
# Heard: a dry air.
#  In guard mode, heard: a dry air.
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: who is that monkey?
#  In guard mode, heard: who is that monkey?
# Heard: ah, they will tune in here.
#  In guard mode, heard: ah, they will tune in here.
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# 🚨 Level 1 Response: Your continued presence is unverified by our security system. You must identify yourself to the camera or exit the property immediately to avoid escalation of security protocols.
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⚠️ Escalation increased: Level 1 → Level 2 (cooldown: 10s)
# → Interaction cooldown expired, proceeding with Level 2 response
# Heard: have a good day.
#  In guard mode, heard: have a good day.
# Heard: to the approach of normal fit
#  In guard mode, heard: to the approach of normal fit
# Heard: butt
#  In guard mode, heard: butt
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# 🚨 Level 2 Response: This is an automated security alert. You are currently on private property and not recognized by our system; please identify yourself or depart the area.
# 📧 Sending Level 2 notifications to authorities
# NOTIFYING AUTHORITIES: UNKNOWN PERSON WARNING: Person has not left after initial warning. Present for 68s, seen 21 times
# Alert logged to security_alerts.log
# ⚠️ webhook_urls is a string, converting to list
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 2 notification methods successful
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 2 response
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: hi
#  In guard mode, heard: hi
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# 🚨 Level 2 Response: You remain on private property and are still not recognized by our system. Please identify yourself immediately or exit the premises.
# 📧 Sending Level 2 notifications to authorities
# NOTIFYING AUTHORITIES: UNKNOWN PERSON WARNING: Person has not left after initial warning. Present for 81s, seen 22 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 2 notification methods successful
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 2 response
# Heard: forhu mannah e e
#  In guard mode, heard: forhu mannah e e
# Heard: so i will trip again...
#  In guard mode, heard: so i will trip again...
# Heard: so again, it's the level 2 thing.
#  In guard mode, heard: so again, it's the level 2 thing.
# Heard: so, think about level 2, where you are now.
#  In guard mode, heard: so, think about level 2, where you are now.
# 🚨 Level 2 Response: You remain on private property and are still not recognized. This is your final opportunity to identify yourself or promptly exit the premises.
# 📧 Sending Level 2 notifications to authorities
# NOTIFYING AUTHORITIES: UNKNOWN PERSON WARNING: Person has not left after initial warning. Present for 94s, seen 23 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 2 notification methods successful
# Heard: you
#  In guard mode, heard: you
# Heard: but we still misident....
#  In guard mode, heard: but we still misident....
# Heard: on the second one.
#  In guard mode, heard: on the second one.
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 2 response
# Heard: very open.
#  In guard mode, heard: very open.
# Heard: you
#  In guard mode, heard: you
# Heard: preparations.
#  In guard mode, heard: preparations.
# Heard: for a big world energy
#  In guard mode, heard: for a big world energy
# Heard: and who there and who there and who there
#  In guard mode, heard: and who there and who there and who there
# Heard: that was the only time.
#  In guard mode, heard: that was the only time.
# 🚨 Level 2 Response: Your continued unauthorized presence on private property has been noted. Further security protocols are now being activated.
# 📧 Sending Level 2 notifications to authorities
# NOTIFYING AUTHORITIES: UNKNOWN PERSON WARNING: Person has not left after initial warning. Present for 110s, seen 24 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 2 notification methods successful
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⚠️ Escalation increased: Level 2 → Level 3 (cooldown: 10s)
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: it's everyone.
#  In guard mode, heard: it's everyone.
# Heard: yeah
#  In guard mode, heard: yeah
# Heard: alright, how many people in
#  In guard mode, heard: alright, how many people in
# 🚨 Level 3 Response: An unrecognized individual has been detected on the property. Please identify yourself to the camera or we request you depart the premises at once.
# 📧 Sending Level 3 notifications to authorities
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings! Present for 122s, seen 25 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# Heard: good.
#  In guard mode, heard: good.
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# 🚨 LEVEL 3 ALERT - Activating alarm protocol
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings!
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# ALARM ACTIVATED - Authorities notified
#  Evidence saved: evidence_person_1_20251013_221111.jpg
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (1.3s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (0.3s remaining)
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you're ready.
#  In guard mode, heard: you're ready.
# 🚨 Level 3 Response: You remain an unrecognized individual on private property. For the security of this premises, you must identify yourself to the camera or depart immediately.
# 📧 Sending Level 3 notifications to authorities
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings! Present for 133s, seen 28 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# Heard: 3-10 minutes until its elise da mus captive
#  In guard mode, heard: 3-10 minutes until its elise da mus captive
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# 🚨 LEVEL 3 ALERT - Activating alarm protocol
#  Evidence saved: evidence_person_1_20251013_221123.jpg
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# ⏳ Interaction cooldown active (0.9s remaining)
# Heard: okay.
#  In guard mode, heard: okay.
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: that's not what i'm gonna leave.
#  In guard mode, heard: that's not what i'm gonna leave.
# Heard: whether....
#  In guard mode, heard: whether....
# Heard: and we've known that
#  In guard mode, heard: and we've known that
# Heard: to get ready again.
#  In guard mode, heard: to get ready again.
# Heard: i got cryptocurrency selling and every visa show is literally
#  In guard mode, heard: i got cryptocurrency selling and every visa show is literally
# Heard: only gets gone, don't be the threat of it, it will still be.
#  In guard mode, heard: only gets gone, don't be the threat of it, it will still be.
# Heard: in doing that.
#  In guard mode, heard: in doing that.
# Heard: see you guys guys
#  In guard mode, heard: see you guys guys
# Heard: responding together.
#  In guard mode, heard: responding together.
# 🚨 Level 3 Response: Your continued presence on this private property remains unauthorized. You are now required to depart the premises without further delay.
# 📧 Sending Level 3 notifications to authorities
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings! Present for 143s, seen 30 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# 🚨 LEVEL 3 ALERT - Activating alarm protocol
#  Evidence saved: evidence_person_1_20251013_221145.jpg
# ✓ Recognized trusted person: unknown
# Heard: i don't know any more questions then...
#  In guard mode, heard: i don't know any more questions then...
# Heard: thank you.
#  In guard mode, heard: thank you.
# Heard: hey, yeah, baby
#  In guard mode, heard: hey, yeah, baby
# ✓ Recognized trusted person: unknown
# Heard: you get
#  In guard mode, heard: you get
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: see you in the next video.
#  In guard mode, heard: see you in the next video.
# Heard: the second or the second.
#  In guard mode, heard: the second or the second.
# Heard: bardong on your makeup…
#  In guard mode, heard: bardong on your makeup…
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you see the level 3 response video
#  In guard mode, heard: you see the level 3 response video
# Heard: you should have gone with your car.
#  In guard mode, heard: you should have gone with your car.
# Heard: i'm sorry, i didn't chill.
#  In guard mode, heard: i'm sorry, i didn't chill.
# Heard: i
#  In guard mode, heard: i
# Heard: in addition with 5
#  In guard mode, heard: in addition with 5
# Heard: trist down like hello
#  In guard mode, heard: trist down like hello
# Heard: well nice, ok.
#  In guard mode, heard: well nice, ok.
# 🚨 Level 3 Response: Your continued unauthorized presence on this private property requires your immediate departure, as no further warnings will be issued.
# 📧 Sending Level 3 notifications to authorities
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings! Present for 180s, seen 31 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# 🚨 LEVEL 3 ALERT - Activating alarm protocol
#  Evidence saved: evidence_person_1_20251013_221227.jpg
# Heard: you
#  In guard mode, heard: you
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: will be general.
#  In guard mode, heard: will be general.
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: y'all ready?
#  In guard mode, heard: y'all ready?
# Heard: little bit raw.
#  In guard mode, heard: little bit raw.
# Heard: you hear the sound?
#  In guard mode, heard: you hear the sound?
# 🚨 Level 3 Response: Your continued unauthorized presence on private property has escalated the alert. This is a final instruction for your immediate departure from the premises.
# 📧 Sending Level 3 notifications to authorities
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings! Present for 207s, seen 32 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# Heard: that's why i didn't or if i don't win already
#  In guard mode, heard: that's why i didn't or if i don't win already
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# 🚨 LEVEL 3 ALERT - Activating alarm protocol
#  Evidence saved: evidence_person_1_20251013_221253.jpg
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: fra lite is chatter bye
#  In guard mode, heard: fra lite is chatter bye
# Heard: a little bit deeper don't you know this? delusions propheciesdoesoglobin cleansing medications words etc.…"..."…"…"…"…" measurable
#  In guard mode, heard: a little bit deeper don't you know this? delusions propheciesdoesoglobin cleansing medications words etc.…"..."…"…"…"…" measurable
# Heard: you
#  In guard mode, heard: you
# Heard: and be
#  In guard mode, heard: and be
# Heard: that opens come in.
#  In guard mode, heard: that opens come in.
# Heard: you
#  In guard mode, heard: you
# Heard: you
#  In guard mode, heard: you
# Heard: open it and it is way a side side.
#  In guard mode, heard: open it and it is way a side side.
# Heard: pichada, have a good one.
#  In guard mode, heard: pichada, have a good one.
# 🚨 Level 3 Response: Your unauthorized presence on private property necessitates immediate departure. This is the final system directive.
# 📧 Sending Level 3 notifications to authorities
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings! Present for 232s, seen 33 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# 🚨 LEVEL 3 ALERT - Activating alarm protocol
#  Evidence saved: evidence_person_1_20251013_221312.jpg
# ✓ Recognized trusted person: unknown
# Heard: ha? you are
#  In guard mode, heard: ha? you are
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: 399
#  In guard mode, heard: 399
# Heard: what if we do this?
#  In guard mode, heard: what if we do this?
# Heard: and then i will be climbing the way. story g g
#  In guard mode, heard: and then i will be climbing the way. story g g
# Heard: here, let's say hi.
#  In guard mode, heard: here, let's say hi.
# Heard: . . . . . . .
#  In guard mode, heard: . . . . . . .
# Heard: i feel hummed how much i around
#  In guard mode, heard: i feel hummed how much i around
# Heard: bye.
#  In guard mode, heard: bye.
# Heard: open with a ton of guy now
#  In guard mode, heard: open with a ton of guy now
# 🚨 Level 3 Response: This is the final automated alert. You are required to vacate the private property immediately.
# 📧 Sending Level 3 notifications to authorities
# NOTIFYING AUTHORITIES: INTRUDER ALERT: Unknown person remains after multiple warnings! Present for 254s, seen 34 times
# Alert logged to security_alerts.log
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# → Attempting to send webhooks to 1 endpoint(s)...
# → Webhook 1/1: https://hooks.slack.com/services/T09KTG171EC/B09JX...
# Heard: i've been a
#  In guard mode, heard: i've been a
# ✅ Webhook alert sent successfully to endpoint 1
# 📊 Webhook summary: 1/1 successful
# 3 notification methods successful
# 🚨 LEVEL 3 ALERT - Activating alarm protocol
#  Evidence saved: evidence_person_1_20251013_221330.jpg
# ✓ Recognized trusted person: unknown
# Heard: you just like manara forever.
#  In guard mode, heard: you just like manara forever.
# Heard: the random
#  In guard mode, heard: the random
# 🚨 UNKNOWN PERSON DETECTED - Starting escalation process
# → Processing unknown person escalation...
# → Interaction cooldown expired, proceeding with Level 3 response
# Heard: andbeupy yeah
#  In guard mode, heard: andbeupy yeah
# Heard: hi, jake here servant
#  In guard mode, heard: hi, jake here servant
# Heard: yeah, bi,'s.' so what about the beginning?
#  In guard mode, heard: yeah, bi,'s.' so what about the beginning?
# Heard: yeah, you know
#  In guard mode, heard: yeah, you know
# Heard: oh
#  In guard mode, heard: oh
#
#  Keyboard interrupt received...
#
#  Shutting down AI Guard system...
# Force cleaning up camera resources...
# Releasing camera...
#  Microphone stream stopped
# Camera released successfully
